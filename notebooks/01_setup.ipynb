# %% [markdown]
# <a href="https://colab.research.google.com/github/hvnguyyen/ml-inventory-forecasting/blob/main/notebooks/01_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Repo & Colab works.")
# Out:
# Repo & Colab works.
