# %% [markdown]
# <a href="https://colab.research.google.com/github/hvnguyyen/ml-inventory-forecasting/blob/main/notebooks/02_data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()

# %%
import pandas as pd
import numpy as np

calendar = pd.read_csv("calendar.csv")
sales = pd.read_csv("sales_train_validation.csv")
prices = pd.read_csv("sell_prices.csv")

print(calendar.shape)
print(sales.shape)
print(prices.shape)

# %%
sales_small = sales.head(100).copy()

id_cols = ["id", "item_id", "dept_id", "cat_id", "store_id", "state_id"]

sales_small_long = sales_small.melt(
    id_vars=id_cols,
    var_name="d",
    value_name="sales"
)

sales_small_with_calendar = sales_small_long.merge(calendar, on="d", how="left")

print(sales_small.shape)
print(sales_small_long.shape)
print(sales_small_with_calendar.shape)
sales_small_with_calendar.head()

# %%
sales_small_with_calendar.head()
